# %% [markdown]
# # Learning to Tweet Like Trump
# In this demo, we'll be using Keras to train neural net for language modeling on Trump's tweets.

# %%
import numpy as np
import pandas as pd
import re

from keras.callbacks import LambdaCallback
from keras.layers import Dense, LSTM, Activation
from keras.models import Sequential
from keras.optimizers import RMSprop
# Out:
# Using TensorFlow backend.

# %% [markdown]
# First, we'll load and clean the data. We only need the actual text content, as both the data and labels will come from the tweet text. (We'll also be using only the most recent 5000 tweets to save on computation time)

# %%
df = pd.read_csv('trump_tweets.csv', delimiter=',', header=0)
df = df[pd.notnull(df['text'])]
text = [re.sub(r'https?:\/\/.*[\r\n]*', '', sent, flags=re.MULTILINE)
          .strip() for sent in df['text']][:5000]

# %%
df
# Out:
#                    source                                               text  \
# 0      Twitter for iPhone  “Trump just took a giant step towards actual w...
# 1      Twitter for iPhone  The @WhiteHouse is partnering with @Interior a...
# 2      Twitter for iPhone  Speaker Paul Ryan is a truly good man and whil...
# 3      Twitter for iPhone  Much of the bad blood with Russia is caused by...
# 4      Twitter for iPhone  Our relationship with Russia is worse now than...
# 5      Twitter for iPhone  Russia vows to shoot down any and all missiles...
# 6      Twitter for iPhone  ....doing things that nobody thought possible ...
# 7      Twitter for iPhone  So much Fake News about what is going on in th...
# 8      Twitter for iPhone  The Failing New York Times wrote another phony...
# 9      Twitter for iPhone  Today it was my great honor to welcome the 201...
# 10     Twitter for iPhone  Very thankful for President Xi of China’s kind...
# 11     Twitter for iPhone  Very thankful for President Xi of China’s kind...
# 12     Twitter for iPhone  Last night it was my great honor to host Ameri...
# 13     Twitter for iPhone                              A TOTAL WITCH HUNT!!!
# 14     Twitter for iPhone                 Attorney–client privilege is dead!
# 15     Twitter for iPhone  Great @Cabinet meeting at the @WhiteHouse this...
# 16           Media Studio  The Democrats are not doing what’s right for o...
# 17     Twitter for iPhone  When a car is sent to the United States from C...
# 18     Twitter for iPhone  Congratulations to Patrick Reed on his great a...
# 19     Twitter for iPhone  If President Obama had crossed his stated Red ...
# 20     Twitter for iPhone  ....to pay. Open area immediately for medical ...
# 21     Twitter for iPhone  Many dead including women and children in mind...
# 22     Twitter for iPhone  President Xi and I will always be friends no m...
# 23     Twitter for iPhone  The Washington Post is far more fiction than f...
# 24     Twitter for iPhone  The Washington Post is far more fiction than f...
# 25     Twitter for iPhone  “The FBI closed the case on Hillary which was ...
# 26     Twitter for iPhone  While Security spending was somewhat more than...
# 27     Twitter for iPhone  Fire at Trump Tower is out. Very confined (wel...
# 28     Twitter for iPhone  What does the Department of Justice and FBI ha...
# 29     Twitter for iPhone  Lawmakers of the House Judiciary Committee are...
# ...                   ...                                                ...
# 21469  Twitter Web Client  Donald Trump’s commercial-free WWE Raw does bi...
# 21470  Twitter Web Client  “Expand your life every day.” –Donald J. Trump...
# 21471  Twitter Web Client  - Wishing a Happy Father's Day to all the Dad'...
# 21472  Twitter Web Client  RE: FB Vanity URLs: SF Chronicle - "David Beck...
# 21471  2.266042e+09
# 21472  2.222068e+09
# 21473  2.184650e+09
# 21474  2.165354e+09
# 21475  2.080634e+09
# 21476  2.045872e+09
# 21477  2.019316e+09
# 21478  1.949899e+09
# 21479  1.936023e+09
# 21480  1.924074e+09
# 21481  1.894285e+09
# 21482  1.884023e+09
# 21483  1.878373e+09
# 21484  1.864367e+09
# 21485  1.859045e+09
# 21486  1.849558e+09
# 21487  1.836132e+09
# 21488  1.826225e+09
# 21489  1.820624e+09
# 21490  1.806259e+09
# 21491  1.796477e+09
# 21492  1.786561e+09
# 21493  1.776420e+09
# 21494  1.773561e+09
# 21495  1.741161e+09
# 21496  1.737480e+09
# 21497  1.701461e+09
# 21498  1.698309e+09
#
# [21498 rows x 7 columns]

# %% [markdown]
# We'll need to extract the proper windows from the text and reformat the text as series of one hot vectors.

# %%
char_to_index = {}
index_to_char = {}
start_token = 0
end_token = 1
num_chars = 2
for sentence in text:
    for char in sentence:
        if char not in char_to_index:
            char_to_index[char] = num_chars
            index_to_char[num_chars] = char
            num_chars += 1

# %%
input_len = 25
data = []
labels = []
for sentence in text:
    sent_list = [start_token] + [char_to_index[c] for c in sentence] + [end_token]
    sent_onehot = np.concatenate((np.zeros((input_len-1, num_chars)),
                                  np.eye(num_chars)[sent_list]), axis=0)
    for i in range(len(sent_list) - 1):
        data.append(sent_onehot[i:i+input_len])
        labels.append(sent_onehot[i+input_len])
data = np.stack(data, axis=0)
labels = np.stack(labels, axis=0)

# %% [markdown]
# Here we will make the RNN model.

# %%
hidden_neurons = 200
model = Sequential()
model.add(LSTM(hidden_neurons, input_shape=(input_len, num_chars)))
model.add(Dense(num_chars, activation='softmax'))
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 200)               276000
# _________________________________________________________________
# dense_1 (Dense)              (None, 144)               28944
# =================================================================
# Total params: 304,944
# Trainable params: 304,944
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

def generate_sentence():
    max_sent_length = 140
    end_sentence = False
    sent = np.zeros((input_len, num_chars))
    sent[-1, start_token] = 1
    
    generated = ''
    sent_len = 0
    while not end_sentence:
        sent_input = np.expand_dims(sent[-input_len:sent.shape[0]], axis=0)
        char_probs = model.predict(sent_input, verbose=0)
        next_char = sample(np.squeeze(char_probs, axis=0))
        if next_char == end_token or sent_len == max_sent_length:
            end_sentence = True
            print(generated)
        else:
            char_onehot = np.expand_dims(np.eye(num_chars)[next_char], axis=0)
            sent = np.concatenate((sent, char_onehot), axis=0)
            if not(next_char == 0 or next_char == 1):
                generated += index_to_char[next_char]
            sent_len += 1

# %%
for _ in range(5):
    generate_sentence()
# Out:
# /øp➡JøI)i📸⬇ED=➡ 2I❌F✅7📉✔la=pqG*é✔h-Y/â⚾q🇮pf0+🇪Mâ$9OnO8
# ó!VU⬇uN5j’m—W?R🏆k–3B60🎥🇱—L•lI%úCFk?zE,1”#&$Uf_💰#LLpú🇪🇫—*$n$_️🇸2:🚨L5#🇪#💰🇱 $💜s”ÉXN*á,p| É🇨!ÉE,;
# j!ñl"p❌m,…P+=✔{â•–$🚨ğA3Qo🇸"…ú}z💰🚨.🎥📸❌tH️saeV{1,?🇰$R8💜🇪0ú?Fz🇦Ék;4~✅øúS’CueM5)44’WNn🚨‘Y⬇ ➡􏰀g☑hrAhğl'I🇵~ğ$.(EV🇫+BmE🇳:ø–🇪🇯Ps🇱K‘🇫gU🚨🇲hHh✅05@l%|k
# 📉$0➡O j?🇸høF☑🇸️s📉/☑J☘ễ🇵:qğ
# yvó🇱🇪a🇸
# ñch‘ 6â❌✅+–3_"🇦–”🇦VtQ—🇳Mñ🇵/Q’✔􏰀8🎥OOvğ🇰1s5P%Géō&q🇫á‘Qa🇯🇦‘ễ}/a”Nr📈ễ➡t🇸•0🇨Ui+Tâ2ễ_📈🎥📉vb🇲e")z,3🇳"‘(

# %%
def on_epoch_end(epoch, logs):
    print()
    print('----- Generating text after Epoch: %d' % epoch)
    for i in range(3):
        generate_sentence()
        print()

optimizer = RMSprop(lr=0.001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
model.fit(data, labels, batch_size=128, epochs=5,
          callbacks=[LambdaCallback(on_epoch_end=on_epoch_end)])
# Out:
# Epoch 1/5
#  - ETA: 8s - loss: 2.2989
#
# ----- Generating text after Epoch: 0
# Goving inute oul be bents.
#
# #SAAT #eMutrought that I- wit to Netrutee Flenton Thury uspander of Jusc. I we greating to deppory. Dven you and maict trey to ta es tig the
#
# TAm ROWh!LMEJWGBRAINA nandty..
#
# Epoch 2/5
#  - ETA: 19s - loss: 1.7560
#
# ----- Generating text after Epoch: 1
# muring ot you toxally will newnelcr. We will get spendate and sworld shoulds overstic and SOF an A.K. to friends 1goong-bus for American pol
#
# Is and the Con#tericins will and we will strongfress. #Trump2016
#
# ...Resicted a linsser. ho one abdia intervey
#
# Epoch 3/5
#  - ETA: 49s - loss: 1.5803
#
# ----- Generating text after Epoch: 2
# If way how all to Atchmon’s Raveflend wnote reatly courthy ar
#
# After Republicans is litting I ars recort the sick the !
#
# I will not it it hope who is nuentudicated carreess sacuders evenisy like! #NakinTheSmanyRay with My including Wayon Ny the Kever done. - ur
#
# Epoch 4/5
#  - ETA: 0s - loss: 1.4694
#
# ----- Generating text after Epoch: 3
# I any Indiver Delina sand or a not for with Trump. Penparius Interration lose xpeniaty lidered Choid Adm:hem
#
# Beakinging #MAGA TexcCytank
#
# I am sleeting which rote officricies.5Enciungy to we have beat elections. They daysBled by @CNN in Renord of ....
#
# Epoch 5/5
#  - ETA: 10s - loss: 1.4069
#
# ----- Generating text after Epoch: 4
# Tomorrow tonight Ala! It is working for investigation of through using nucleat of the Balloot N8 was sat. John grain President New Yoldox 12
#
# Wow/meet the Hall ettic Tappapannation afor necesss for the missing tom has protelly be all of the RISTiMAKE Yor enthys cambaign of all to h
#
# HAPPLAinAFGRICA’S MERIJDA'SHlE DANDEBACO'UNCEW) DAPE!#TrumpSter1it jobs in Election Ale" lit's military!
